# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /Users/abhayanand/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
DVC2 = pd.read_csv('India Boi.csv')
DVC2
# Out:
#            Time           BSE         NIFTY   Cases  Deaths  Recovered
# 0    2020-02-02  40723.488280  11962.099610       1       0          0
# 1    2020-02-03  39872.308590  11707.900390       1       0          0
# 2    2020-02-04  40789.378910  11979.650390       1       0          0
# 3    2020-02-05  41142.660160  12089.150390       2       0          0
# 4    2020-02-06  41306.031250  12137.950200       2       0          0
# ..          ...           ...           ...     ...     ...        ...
# 153  2020-07-05  36021.421875  10799.650391  605224   17849     359904
# 154  2020-07-06  36487.281250  10705.750000  627171   18227     379903
# 155  2020-07-07  36674.519531  10705.750000  649889   18671     394320
# 156  2020-07-08  36329.011719  10705.750000  673907   19282     409066
# 157  2020-07-09  36737.691406  10813.450195  697849   19703     424895
#
# [158 rows x 6 columns]

# %%
DVC2.describe()
# Out:
#                 BSE         NIFTY          Cases        Deaths      Recovered
# count    158.000000    158.000000     158.000000    158.000000     158.000000
# mean   34017.418686   9992.080419  112453.259494   3381.822785   58586.626582
# std     4011.477568   1188.612352  176745.767834   5293.621140  102518.138439
# min    25981.240230   7610.250000       1.000000      0.000000       0.000000
# 25%    31104.020510   9111.900391      45.500000      0.000000       4.000000
# 50%    33717.621090   9870.525391   15045.000000    493.500000    2658.500000
# 75%    36252.114258  10705.750000  156292.500000   4487.000000   66866.500000
# max    41565.898440  12201.200200  697849.000000  19703.000000  424895.000000

# %%
sns.boxplot(DVC2['BSE'])
plt.savefig('BSE box.png', dpi = 300)

# %%
sns.boxplot(DVC2['NIFTY'])
plt.savefig('NIFTY box.png', dpi = 300)

# %%
sns.boxplot(DVC2['Cases'])
plt.savefig('Cases box.png', dpi = 300)

# %%
sns.boxplot(DVC2['Deaths'])
plt.savefig('Deaths box.png', dpi = 300)

# %%
sns.boxplot(DVC2['Recovered'])
plt.savefig('Recovered box.png', dpi = 300)

# %%
sns.pointplot(DVC2['Time'], DVC2['BSE'])
plt.savefig('Time X BSE.png', dpi = 300)

# %%
sns.pointplot(DVC2['Time'], DVC2['NIFTY'])
plt.savefig('Time X NIFTY.png', dpi = 300)

# %%
sns.pointplot(DVC2['Time'], DVC2['Cases'])
plt.savefig('Time X Cases.png', dpi = 300)

# %%
sns.pointplot(DVC2['Time'], DVC2['Deaths'])
plt.savefig('Time X Deaths.png', dpi = 300)

# %%
sns.pointplot(DVC2['Time'], DVC2['Recovered'])
plt.savefig('Time X Recovered.png', dpi = 300)

# %%
sns.jointplot(DVC2['Cases'],DVC2['BSE'], kind='reg')
plt.savefig('Cases X BSE.png', dpi = 300)

# %%
sns.jointplot(DVC2['Deaths'],DVC2['BSE'], kind='reg')
plt.savefig('Deaths X BSE.png', dpi = 300)

# %%
sns.jointplot(DVC2['Recovered'],DVC2['BSE'], kind='reg')
plt.savefig('Recovered X BSE.png', dpi = 300)

# %%
sns.jointplot(DVC2['Cases'],DVC2['NIFTY'], kind='reg')
plt.savefig('Cases X NIFTY.png', dpi = 300)

# %%
sns.jointplot(DVC2['Deaths'],DVC2['NIFTY'], kind='reg')
plt.savefig('Deaths X NIFTY.png', dpi = 300)

# %%
sns.jointplot(DVC2['Recovered'],DVC2['NIFTY'], kind='reg')
plt.savefig('Recovered X NIFTY.png', dpi = 300)
