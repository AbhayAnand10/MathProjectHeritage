# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /Users/abhayanand/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
DVC2 = pd.read_csv('USA boi.csv')
DVC2
# Out:
#            Time      S&P 500     DOW JONES        NASDAQ    Cases  Deaths  \
# 0    2020-01-23  3325.540039  29160.089840   9402.480469        1       0
# 1    2020-01-24  3295.469971  28989.730470   9314.910156        1       0
# 2    2020-01-25  3295.469971  28989.730470   9314.910156        1       0
# 3    2020-01-26  3295.469971  28989.730470   9314.910156        1       0
# 4    2020-01-27  3243.629883  28535.800780   9139.309570        2       0
# ..          ...          ...           ...           ...      ...     ...
# 163  2020-07-04  3130.010010  25827.359375  10207.629883  2724433  127858
# 164  2020-07-05  3179.719971  25827.359375  10433.650391  2776366  128481
# 165  2020-07-06  3145.320068  26287.029297  10343.889648  2833552  129226
# 166  2020-07-07  3169.939941  25890.179688  10492.500000  2877238  129408
# 167  2020-07-08  3152.050049  26067.279297  10547.750000  2923432  129643
#
#      Recovered
# 0            0
# 1            0
# 2            0
# ...

# %%
DVC2.describe()
# Out:
#            S&P 500     DOW JONES        NASDAQ         Cases         Deaths  \
# count   168.000000    168.000000    168.000000  1.680000e+02     168.000000
# mean   2967.369992  25168.074266   8966.548648  8.661619e+05   46521.166667
# std     273.806713   2583.091330    897.586926  9.175833e+05   49374.642957
# min    2237.399902  18591.929690   6860.669922  1.000000e+00       0.000000
# 25%    2814.887512  23685.419920   8553.637940  9.950000e+01       5.000000
# 50%    2975.565064  25383.109375   9150.940430  5.700825e+05   22878.500000
# 75%    3147.002563  26766.887693   9715.467285  1.662986e+06   97676.500000
# max    3386.149902  29551.419920  10547.750000  2.923432e+06  129643.000000
#
#            Recovered
# count     168.000000
# mean   207378.803571
# std    267235.838413
# min         0.000000
# 25%         7.000000
# 50%     53399.500000
# 75%    393628.750000
# max    953420.000000

# %%
sns.boxplot(DVC2['S&P 500'])
plt.savefig('save_as_a_png.png', dpi = 300)

# %%
sns.boxplot(DVC2['DOW JONES'])
plt.savefig('DOW JONES box.png', dpi = 300)

# %%
sns.boxplot(DVC2['NASDAQ'])
plt.savefig('NASDAQ box.png', dpi = 300)

# %%
sns.boxplot(DVC2['Cases'])
plt.savefig('Cases box.png', dpi = 300)

# %%
sns.boxplot(DVC2['Deaths'])
plt.savefig('Deaths box.png', dpi = 300)

# %%
sns.boxplot(DVC2['Recovered'])
plt.savefig('Recovered box.png', dpi = 300)

# %%
sns.pointplot(DVC2['Time'], DVC2['S&P 500'])
plt.savefig('Time X S&P 500.png', dpi = 300)

# %%
sns.pointplot(DVC2['Time'], DVC2['DOW JONES'])
plt.savefig('Time X DOW JONES.png', dpi = 300)

# %%
sns.pointplot(DVC2['Time'], DVC2['NASDAQ'])
plt.savefig('Time X NASDAQ.png', dpi = 300)

# %%
sns.pointplot(DVC2['Time'], DVC2['Cases'])
plt.savefig('Time X Cases.png', dpi = 300)

# %%
sns.pointplot(DVC2['Time'], DVC2['Deaths'])
plt.savefig('Time X Deaths.png', dpi = 300)

# %%
sns.pointplot(DVC2['Time'], DVC2['Recovered'])
plt.savefig('Time X Recovered.png', dpi = 300)

# %%
sns.jointplot(DVC2['Cases'],DVC2['S&P 500'], kind='reg')
plt.savefig('Cases X S&P 500.png', dpi = 300)

# %%
sns.jointplot(DVC2['Deaths'],DVC2['S&P 500'], kind='reg')
plt.savefig('Deaths X S&P 500.png', dpi = 300)

# %%
sns.jointplot(DVC2['Recovered'],DVC2['S&P 500'], kind='reg')
plt.savefig('Recovered X S&P 500.png', dpi = 300)

# %%
sns.jointplot(DVC2['Cases'],DVC2['DOW JONES'], kind='reg')
plt.savefig('Cases X DOW JONES.png', dpi = 300)

# %%
sns.jointplot(DVC2['Deaths'],DVC2['DOW JONES'], kind='reg')
plt.savefig('Deaths X DOW JONES.png', dpi = 300)

# %%
sns.jointplot(DVC2['Recovered'],DVC2['DOW JONES'], kind='reg')
plt.savefig('Recovered X DOW JONES.png', dpi = 300)

# %%
sns.jointplot(DVC2['Cases'],DVC2['NASDAQ'], kind='reg')
plt.savefig('Cases X NASDAQ.png', dpi = 300)

# %%
sns.jointplot(DVC2['Deaths'],DVC2['NASDAQ'], kind='reg')
plt.savefig('Deaths X NASDAQ.png', dpi = 300)

# %%
sns.jointplot(DVC2['Recovered'],DVC2['NASDAQ'], kind='reg')
plt.savefig('Recovered X NASDAQ.png', dpi = 300)
