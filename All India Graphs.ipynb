# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
DVC2 = pd.read_csv('India Boi.csv')
DVC2
# Out:
#            Time          BSE         NIFTY   Cases  Deaths  Recovered
# 0    2020-02-02  40723.48828  11962.099610       1       0          0
# 1    2020-02-03  39872.30859  11707.900390       1       0          0
# 2    2020-02-04  40789.37891  11979.650390       1       0          0
# 3    2020-02-05  41142.66016  12089.150390       2       0          0
# 4    2020-02-06  41306.03125  12137.950200       2       0          0
# ..          ...          ...           ...     ...     ...        ...
# 111  2020-05-23  30672.58984   9039.250000  112359    3435      48553
# 112  2020-05-24  30672.58984   9039.250000  118447    3583      51824
# 113  2020-05-25  30672.58984   9039.250000  125101    3720      54385
# 114  2020-05-26  30609.30078   9029.049805  131868    3867      57692
# 115  2020-05-27  31605.22070   9314.950195  138845    4021      60706
#
# [116 rows x 6 columns]

# %%
sns.jointplot(DVC2['Cases'],DVC2['NIFTY'], kind='scatter')

# %%
sns.jointplot(DVC2['Deaths'],DVC2['NIFTY'], kind='scatter')

# %%
sns.jointplot(DVC2['Recovered'],DVC2['NIFTY'], kind='scatter')

# %%
sns.jointplot(DVC2['Cases'],DVC2['BSE'], kind='scatter')

# %%
sns.jointplot(DVC2['Deaths'],DVC2['BSE'], kind='scatter')

# %%
sns.jointplot(DVC2['Recovered'],DVC2['BSE'], kind='scatter')
