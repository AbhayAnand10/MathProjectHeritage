# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
DVC2 = pd.read_csv('Stock and Covid-19 DATA (Raw format for model) - Sheet1 copy.csv')
DVC2
# Out:
#            Date  S&P 500 (US)  DOW JONES (US)  NASDAQ (US)  Cases (US)  \
# 0    2020-02-02   3225.520020     28256.02930  9150.940430           6
# 1    2020-02-03   3248.919922     28399.81055  9273.400391           7
# 2    2020-02-04   3297.590088     28807.63086  9467.969727           8
# 3    2020-02-05   3334.689941     29290.84961  9508.679688          11
# 4    2020-02-06   3345.780029     29379.76953  9572.150391          11
# ..          ...           ...             ...          ...         ...
# 111  2020-05-23   2955.449951     24465.16016  9324.589844     1551853
# 112  2020-05-24   2955.449951     24465.16016  9324.589844     1577287
# 113  2020-05-25   2955.449951     24465.16016  9324.589844     1601434
# 114  2020-05-26   2991.770020     24995.10938  9340.219727     1622670
# 115  2020-05-27   2992.149902     25321.58008  9344.371094     1643238
#
#      Deaths (US)  Recovered (US)  BSE (India)  NIFTY 50 (India)  \
# ...

# %%
sns.jointplot(DVC2['Deaths (US)'],DVC2['S&P 500 (US)'], kind='scatter')

# %%
sns.jointplot(DVC2['Cases (US)'],DVC2['S&P 500 (US)'], kind='scatter')

# %%
sns.jointplot(DVC2['Recovered (US)'],DVC2['S&P 500 (US)'], kind='scatter')

# %%
sns.jointplot(DVC2['Deaths (US)'],DVC2['DOW JONES (US)'], kind='scatter')

# %%
sns.jointplot(DVC2['Cases (US)'],DVC2['DOW JONES (US)'], kind='scatter')

# %%
sns.jointplot(DVC2['Recovered (US)'],DVC2['DOW JONES (US)'], kind='scatter')

# %%
sns.jointplot(DVC2['Deaths (US)'],DVC2['NASDAQ (US)'], kind='scatter')

# %%
sns.jointplot(DVC2['Cases (US)'],DVC2['NASDAQ (US)'], kind='scatter')

# %%
sns.jointplot(DVC2['Recovered (US)'],DVC2['NASDAQ (US)'], kind='scatter')
